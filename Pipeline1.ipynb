# %%
import glob
import json
import re
from datetime import datetime
from pymongo import MongoClient

client = MongoClient("mongodb://localhost:27017")
db = client["spotify_db"]
col = db.artist_daily_streams


files = sorted(glob.glob("kworb/spotify_artist_top10_albums_*.json"))

date_pattern = re.compile(r"spotify_artist_top10_albums_(\d{8})\.json")

for file in files:
    match = date_pattern.search(file)
    
    if match:
        date_str = match.group(1)
        date = datetime.strptime(date_str, "%Y%m%d").strftime("%Y-%m-%d")
    else:
        continue

    with open(file, "r") as f:
        records = json.load(f)

    for r in records:
        daily_raw = r.get("daily", "").replace(",", "")
        daily = int(daily_raw) if daily_raw.isdigit() else 0
        col.insert_one({
            "artist_name": r["artist_name"],
            "artist_id": r["artist_id"],
            "daily": daily,
            "date": date})

print("Data inserted successfully.")
# Out:
# Data inserted successfully.

# %%
with open("filtered_artist_ids.json", "r") as f:
    filtered_ids = json.load(f)

# %%
pipeline = [

    # ---------------------------------------------
    # 0. Filter only artists from the SQLite results
    # ---------------------------------------------
    {"$match": {"artist_id": {"$in": filtered_ids}}},

    # ---------------------------------------------
    # Original pipeline continues
    # ---------------------------------------------
    {"$sort": {"artist_name": 1, "date": 1}},

    {
        "$group": {
            "_id": {
                "artist_name": "$artist_name",
                "artist_id": "$artist_id",
                "date": "$date"
            },
            "daily_streams": {"$sum": "$daily"}
        }
    },

    {
        "$group": {
            "_id": "$artist_id"     
            },
            "streams": {
                "$push": {
                    "artist_name": "$_id.artist_name",
                    "date": "$_id.date",
                    "daily_streams": "$daily_streams"
                }
            }
        },

    {
        "$project": {
            "_id": 0,
            "artist_id": "$_id",
            "streams": {
                "$sortArray": {
                    "input": "$streams",
                    "sortBy": { "date": 1 }
                }
            }
        }
    },
    {"$sort": {"artist_name": 1}}
]

# %%
source_col = db.artist_daily_streams
target_col = db.artist_time_series   

results = list(source_col.aggregate(pipeline))

target_col.delete_many({})  # clears old results
target_col.insert_many(results)

# print("Aggregation result stored in 'artist_time_series' collection.")
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[20], line 4
#       1 source_col = db.artist_daily_streams
#       2 target_col = db.artist_time_series
# ----> 4 results = list(source_col.aggregate(pipeline))
#       6 target_col.delete_many({})  # clears old results
#       7 target_col.insert_many(results)
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/synchronous/collection.py:2979, in Collection.aggregate(self, pipeline, session, let, comment, **kwargs)
#    2902 """Perform an aggregation using the aggregation framework on this
#    2903 collection.
#    2904
#    (...)   2976     https://mongodb.com/docs/manual/reference/command/aggregate
#    2977 """
#    2978 with self._database.client._tmp_session(session, close=False) as s:
# -> 2979     return self._aggregate(
#    2980         _CollectionAggregationCommand,
#    2981         pipeline,
#    2982         CommandCursor,
#    2983         session=s,
#    2984         explicit_session=session is not None,
#    2985         let=let,
#    2986         comment=comment,
#    2987         **kwargs,
#    2988     )
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/synchronous/collection.py:2886, in Collection._aggregate(self, aggregation_command, pipeline, cursor_class, session, explicit_session, let, comment, **kwargs)
#    2875     kwargs["comment"] = comment
#    2876 cmd = aggregation_command(
#    2877     self,
#    2878     cursor_class,
#    (...)   2883     user_fields={"cursor": {"firstBatch": 1}},
#    2884 )
# -> 2886 return self._database.client._retryable_read(
#    2887     cmd.get_cursor,
#    2888     cmd.get_read_preference(session),  # type: ignore[arg-type]
#    2889     session,
#    2890     retryable=not cmd._performs_write,
#    2891     operation=_Op.AGGREGATE,
#    2892 )
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:2041, in MongoClient._retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    2036 # Ensure that the client supports retrying on reads and there is no session in
#    2037 # transaction, otherwise, we will not support retry behavior for this call.
#    2038 retryable = bool(
#    2039     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    2040 )
# -> 2041 return self._retry_internal(
#    2042     func,
#    2043     session,
#    2044     None,
#    2045     operation,
#    2046     is_read=True,
#    2047     address=address,
#    2048     read_pref=read_pref,
#    2049     retryable=retryable,
#    2050     operation_id=operation_id,
#    2051 )
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:2008, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1971 @_csot.apply
#    1972 def _retry_internal(
#    1973     self,
#    (...)   1982     operation_id: Optional[int] = None,
#    1983 ) -> T:
#    1984     """Internal retryable helper for all client transactions.
#    1985
#    1986     :param func: Callback function we want to retry
#    (...)   1995     :return: Output of the calling func()
#    1996     """
#    1997     return _ClientConnectionRetryable(
#    1998         mongo_client=self,
#    1999         func=func,
#    2000         bulk=bulk,
#    2001         operation=operation,
#    2002         is_read=is_read,
#    2003         session=session,
#    2004         read_pref=read_pref,
#    2005         address=address,
#    2006         retryable=retryable,
#    2007         operation_id=operation_id,
# -> 2008     ).run()
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:2745, in _ClientConnectionRetryable.run(self)
#    2743 self._check_last_error(check_csot=True)
#    2744 try:
# -> 2745     return self._read() if self._is_read else self._write()
#    2746 except ServerSelectionTimeoutError:
#    2747     # The application may think the write was never attempted
#    2748     # if we raise ServerSelectionTimeoutError on the retry
#    2749     # attempt. Raise the original exception instead.
#    2750     self._check_last_error()
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:2906, in _ClientConnectionRetryable._read(self)
#    2898 if self._retrying:
#    2899     _debug_log(
#    2900         _COMMAND_LOGGER,
#    2901         message=f"Retrying read attempt number {self._attempt_number}",
#    (...)   2904         operationId=self._operation_id,
#    2905     )
# -> 2906 return self._func(self._session, self._server, conn, read_pref)
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/synchronous/aggregation.py:164, in _AggregationCommand.get_cursor(self, session, server, conn, read_preference)
#     161     write_concern = None
#     163 # Run command.
# --> 164 result = conn.command(
#     165     self._database.name,
#     166     cmd,
#     167     read_preference,
#     168     self._target.codec_options,
#     169     parse_write_concern_error=True,
#     170     read_concern=read_concern,
#     171     write_concern=write_concern,
#     172     collation=self._collation,
#     173     session=session,
#     174     client=self._database.client,
#     175     user_fields=self._user_fields,
#     176 )
#     178 if self._result_processor:
#     179     self._result_processor(result, conn)
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/synchronous/helpers.py:47, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      44 from pymongo.synchronous.pool import Connection
#      46 try:
# ---> 47     return func(*args, **kwargs)
#      48 except OperationFailure as exc:
#      49     if no_reauth:
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/synchronous/pool.py:413, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     411     self._raise_if_not_writable(unacknowledged)
#     412 try:
# --> 413     return command(
#     414         self,
#     415         dbname,
#     416         spec,
#     417         self.is_mongos,
#     418         read_preference,
#     419         codec_options,
#     420         session,
#     421         client,
#     422         check,
#     423         allowable_errors,
#     424         self.address,
#     425         listeners,
#     426         self.max_bson_size,
#     427         read_concern,
#     428         parse_write_concern_error=parse_write_concern_error,
#     429         collation=collation,
#     430         compression_ctx=self.compression_context,
#     431         use_op_msg=self.op_msg_enabled,
#     432         unacknowledged=unacknowledged,
#     433         user_fields=user_fields,
#     434         exhaust_allowed=exhaust_allowed,
#     435         write_concern=write_concern,
#     436     )
#     437 except (OperationFailure, NotPrimaryError):
#     438     raise
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/synchronous/network.py:212, in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     210             client._process_response(response_doc, session)
#     211         if check:
# --> 212             helpers_shared._check_command_response(
#     213                 response_doc,
#     214                 conn.max_wire_version,
#     215                 allowable_errors,
#     216                 parse_write_concern_error=parse_write_concern_error,
#     217             )
#     218 except Exception as exc:
#     219     duration = datetime.datetime.now() - start
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/helpers_shared.py:284, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error, pool_opts)
#     281 elif code == 43:
#     282     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 284 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: A pipeline stage specification object must contain exactly one field., full error: {'ok': 0.0, 'errmsg': 'A pipeline stage specification object must contain exactly one field.', 'code': 40323, 'codeName': 'Location40323'}

# %%
results[5]
# Out:
# {'artist_name': 'Chance the Rapper',
#  'streams': [{'date': '2025-11-30', 'daily_streams': 2307309},
#   {'date': '2025-12-01', 'daily_streams': 2307309},
#   {'date': '2025-12-02', 'daily_streams': 1406376},
#   {'date': '2025-12-03', 'daily_streams': 703188}],
#  '_id': ObjectId('693212234de81cf692a3f9bb')}

# %%
# Optiional for data files export
import pandas as pd

rows = []

for doc in results:  # results is a list of MongoDB documents
    artist = doc["artist_name"]
    
    for entry in doc["streams"]:
        rows.append({
            "artist_name": artist,
            "date": entry["date"],
            "daily_streams": entry["daily_streams"]
        })

df = pd.DataFrame(rows)
df.head()
# Out:
#   artist_name        date  daily_streams
# 0    2 Chainz  2025-11-30        3033624
# 1    2 Chainz  2025-12-01        3033624
# 2    2 Chainz  2025-12-02        2022416
# 3    2 Chainz  2025-12-03         925735
# 4      Alex G  2025-11-30        6667881

# %%
df.to_csv("all_artists_streams.csv", index=False)
