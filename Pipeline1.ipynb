# %%
import glob
import json
import re
from datetime import datetime
from pymongo import MongoClient

client = MongoClient("mongodb://localhost:27017")
db = client["spotify_db"]
col = db.artist_daily_streams


files = sorted(glob.glob("kworb/spotify_artist_top10_albums_*.json"))

date_pattern = re.compile(r"spotify_artist_top10_albums_(\d{8})\.json")

for file in files:
    match = date_pattern.search(file)
    
    if match:
        date_str = match.group(1)
        date = datetime.strptime(date_str, "%Y%m%d").strftime("%Y-%m-%d")
    else:
        continue

    with open(file, "r") as f:
        records = json.load(f)

    for r in records:
        daily_raw = r.get("daily", "").replace(",", "")
        daily = int(daily_raw) if daily_raw.isdigit() else 0
        col.insert_one({
            "artist_name": r["artist_name"],
            "artist_id": r["artist_id"],
            "daily": daily,
            "date": date})

print("Data inserted successfully.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 31
#      29         daily_raw = r.get("daily", "").replace(",", "")
#      30         daily = int(daily_raw) if daily_raw.isdigit() else 0
# ---> 31         col.insert_one({
#      32             "artist_name": r["artist_name"],
#      33             "artist_id": r["artist_id"],
#      34             "daily": daily,
#      35             "date": date})
#      37 print("Data inserted successfully.")
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/synchronous/collection.py:891, in Collection.insert_one(self, document, bypass_document_validation, session, comment)
#     887     document["_id"] = ObjectId()  # type: ignore[index]
#     889 write_concern = self._write_concern_for(session)
#     890 return InsertOneResult(
# --> 891     self._insert_one(
#     892         document,
#     893         ordered=True,
#     894         write_concern=write_concern,
#     895         op_id=None,
#     896         bypass_doc_val=bypass_document_validation,
#     897         session=session,
#     898         comment=comment,
#     899     ),
#     900     write_concern.acknowledged,
#     901 )
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/synchronous/collection.py:831, in Collection._insert_one(self, doc, ordered, write_concern, op_id, bypass_doc_val, session, comment)
#     819     result = conn.command(
#     820         self._database.name,
#     821         command,
#    (...)    826         retryable_write=retryable_write,
#     827     )
#     829     _check_write_command_response(result)
# --> 831 self._database.client._retryable_write(
#     832     acknowledged, _insert_command, session, operation=_Op.INSERT
#     833 )
#     835 if not isinstance(doc, RawBSONDocument):
#     836     return doc.get("_id")
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:2076, in MongoClient._retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    2062 """Execute an operation with consecutive retries if possible
#    2063
#    2064 Returns func()'s return value on success. On error retries the same
#    (...)   2073 :param bulk: bulk abstraction to execute operations in bulk, defaults to None
#    2074 """
#    2075 with self._tmp_session(session) as s:
# -> 2076     return self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:1962, in MongoClient._retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1957 # Ensure that the options supports retry_writes and there is a valid session not in
#    1958 # transaction, otherwise, we will not support retry behavior for this txn.
#    1959 retryable = bool(
#    1960     retryable and self.options.retry_writes and session and not session.in_transaction
#    1961 )
# -> 1962 return self._retry_internal(
#    1963     func=func,
#    1964     session=session,
#    1965     bulk=bulk,
#    1966     operation=operation,
#    1967     retryable=retryable,
#    1968     operation_id=operation_id,
#    1969 )
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:2008, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1971 @_csot.apply
#    1972 def _retry_internal(
#    1973     self,
#    (...)   1982     operation_id: Optional[int] = None,
#    1983 ) -> T:
#    1984     """Internal retryable helper for all client transactions.
#    1985
#    1986     :param func: Callback function we want to retry
#    (...)   1995     :return: Output of the calling func()
#    1996     """
#    1997     return _ClientConnectionRetryable(
#    1998         mongo_client=self,
#    1999         func=func,
#    2000         bulk=bulk,
#    2001         operation=operation,
#    2002         is_read=is_read,
#    2003         session=session,
#    2004         read_pref=read_pref,
#    2005         address=address,
#    2006         retryable=retryable,
#    2007         operation_id=operation_id,
# -> 2008     ).run()
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:2745, in _ClientConnectionRetryable.run(self)
#    2743 self._check_last_error(check_csot=True)
#    2744 try:
# -> 2745     return self._read() if self._is_read else self._write()
#    2746 except ServerSelectionTimeoutError:
#    2747     # The application may think the write was never attempted
#    2748     # if we raise ServerSelectionTimeoutError on the retry
#    2749     # attempt. Raise the original exception instead.
#    2750     self._check_last_error()
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:2877, in _ClientConnectionRetryable._write(self)
#    2869         if self._retrying:
#    2870             _debug_log(
#    2871                 _COMMAND_LOGGER,
#    2872                 message=f"Retrying write attempt number {self._attempt_number}",
#    (...)   2875                 operationId=self._operation_id,
#    2876             )
# -> 2877         return self._func(self._session, conn, self._retryable)  # type: ignore
#    2878 except PyMongoError as exc:
#    2879     if not self._retryable:
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/synchronous/collection.py:819, in Collection._insert_one.<locals>._insert_command(session, conn, retryable_write)
#     816 if bypass_doc_val is not None:
#     817     command["bypassDocumentValidation"] = bypass_doc_val
# --> 819 result = conn.command(
#     820     self._database.name,
#     821     command,
#     822     write_concern=write_concern,
#     823     codec_options=self._write_response_codec_options,
#     824     session=session,
#     825     client=self._database.client,
#     826     retryable_write=retryable_write,
#     827 )
#     829 _check_write_command_response(result)
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/synchronous/helpers.py:47, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      44 from pymongo.synchronous.pool import Connection
#      46 try:
# ---> 47     return func(*args, **kwargs)
#      48 except OperationFailure as exc:
#      49     if no_reauth:
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/synchronous/pool.py:441, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     439 # Catch socket.error, KeyboardInterrupt, CancelledError, etc. and close ourselves.
#     440 except BaseException as error:
# --> 441     self._raise_connection_failure(error)
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/synchronous/pool.py:413, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     411     self._raise_if_not_writable(unacknowledged)
#     412 try:
# --> 413     return command(
#     414         self,
#     415         dbname,
#     416         spec,
#     417         self.is_mongos,
#     418         read_preference,
#     419         codec_options,
#     420         session,
#     421         client,
#     422         check,
#     423         allowable_errors,
#     424         self.address,
#     425         listeners,
#     426         self.max_bson_size,
#     427         read_concern,
#     428         parse_write_concern_error=parse_write_concern_error,
#     429         collation=collation,
#     430         compression_ctx=self.compression_context,
#     431         use_op_msg=self.op_msg_enabled,
#     432         unacknowledged=unacknowledged,
#     433         user_fields=user_fields,
#     434         exhaust_allowed=exhaust_allowed,
#     435         write_concern=write_concern,
#     436     )
#     437 except (OperationFailure, NotPrimaryError):
#     438     raise
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/synchronous/network.py:198, in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     196     response_doc: _DocumentOut = {"ok": 1}
#     197 else:
# --> 198     reply = receive_message(conn, request_id)
#     199     conn.more_to_come = reply.more_to_come
#     200     unpacked_docs = reply.unpack_response(
#     201         codec_options=codec_options, user_fields=user_fields
#     202     )
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/network_layer.py:759, in receive_message(conn, request_id, max_message_size)
#     757         deadline = None
#     758 # Ignore the response's request id.
# --> 759 length, _, response_to, op_code = _UNPACK_HEADER(receive_data(conn, 16, deadline))
#     760 # No request_id for exhaust cursor "getMore".
#     761 if request_id is not None:
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/network_layer.py:353, in receive_data(conn, length, deadline)
#     350             short_timeout = _POLL_TIMEOUT
#     351         conn.set_conn_timeout(short_timeout)
# --> 353     chunk_length = conn.conn.recv_into(mv[bytes_read:])
#     354 except BLOCKING_IO_ERRORS:
#     355     if conn.cancel_context.cancelled:
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/network_layer.py:469, in NetworkingInterface.recv_into(self, buffer)
#     468 def recv_into(self, buffer: bytes) -> int:
# --> 469     return self.conn.recv_into(buffer)
#
# KeyboardInterrupt:

# %%
with open("filtered_artist_ids.json", "r") as f:
    filtered_ids = json.load(f)

# %%
pipeline = [

    # ---------------------------------------------
    # 0. Filter only artists from the SQLite results
    # ---------------------------------------------
    {"$match": {"artist_id": {"$in": filtered_ids}}},

    # ---------------------------------------------
    # Original pipeline continues
    # ---------------------------------------------
    {"$sort": {"artist_name": 1, "date": 1}},

    {
        "$group": {
            "_id": {
                "artist_name": "$artist_name",
                "date": "$date"
            },
            "daily_streams": {"$sum": "$daily"}
        }
    },

    {
        "$group": {
            "_id": "$_id.artist_name",
            "streams": {
                "$push": {
                    "date": "$_id.date",
                    "daily_streams": "$daily_streams"
                }
            }
        }
    },

    {
        "$project": {
            "_id": 0,
            "artist_name": "$_id",
            "streams": {
                "$sortArray": {
                    "input": "$streams",
                    "sortBy": { "date": 1 }
                }
            }
        }
    },

    {"$sort": {"artist_name": 1}}
]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       1 pipeline = [
#       2
#       3     # ---------------------------------------------
#       4     # 0. Filter only artists from the SQLite results
#       5     # ---------------------------------------------
# ----> 6     {"$match": {"artist_id": {"$in": filtered_ids}}},
#       7
#       8     # ---------------------------------------------
#       9     # Original pipeline continues
#      10     # ---------------------------------------------
#      11     {"$sort": {"artist_name": 1, "date": 1}},
#      12
#      13     {
#      14         "$group": {
#      15             "_id": {
#      16                 "artist_name": "$artist_name",
#      17                 "date": "$date"
#      18             },
#      19             "daily_streams": {"$sum": "$daily"}
#      20         }
#      21     },
#      22
#      23     {
#      24         "$group": {
#      25             "_id": "$_id.artist_name",
#      26             "streams": {
#      27                 "$push": {
#      28                     "date": "$_id.date",
#      29                     "daily_streams": "$daily_streams"
#      30                 }
#      31             }
#      32         }
#      33     },
#      34
#      35     {
#      36         "$project": {
#      37             "_id": 0,
#      38             "artist_name": "$_id",
#      39             "streams": {
#      40                 "$sortArray": {
#      41                     "input": "$streams",
#      42                     "sortBy": { "date": 1 }
#      43                 }
#      44             }
#      45         }
#      46     },
#      47
#      48     {"$sort": {"artist_name": 1}}
#      49 ]
#
# NameError: name 'filtered_ids' is not defined

# %%
source_col = db.artist_daily_streams
target_col = db.artist_time_series   

results = list(source_col.aggregate(pipeline))

target_col.delete_many({})  # clears old results
target_col.insert_many(results)

# print("Aggregation result stored in 'artist_time_series' collection.")

# %%
# Optiional for data files export
# mongoexport \
#   --uri="mongodb://localhost:27017" \
#   --db spotify_db \
#   --collection target_col \
#   --out target_col.json
