# %%
import glob
import json
import re
from datetime import datetime
from pymongo import MongoClient

client = MongoClient("mongodb://localhost:27017")
db = client["spotify_db"]
col = db.artist_daily_streams


files = sorted(glob.glob("kworb/spotify_artist_top10_albums_*.json"))

date_pattern = re.compile(r"spotify_artist_top10_albums_(\d{8})\.json")

for file in files:
    match = date_pattern.search(file)
    
    if match:
        date_str = match.group(1)
        date = datetime.strptime(date_str, "%Y%m%d").strftime("%Y-%m-%d")
    else:
        continue

    with open(file, "r") as f:
        records = json.load(f)

    for r in records:
        daily_raw = r.get("daily", "").replace(",", "")
        daily = int(daily_raw) if daily_raw.isdigit() else 0
        col.insert_one({
            "artist_name": r["artist_name"],
            "artist_id": r["artist_id"],
            "daily": daily,
            "date": date})

print("Data inserted successfully.")
# Out:
# Data inserted successfully.

# %%
with open("filtered_artist_ids.json", "r") as f:
    filtered_ids = json.load(f)

# %%
pipeline = [

    # 0. Keep only selected artists
    {"$match": {"artist_id": {"$in": filtered_ids}}},

    # 1. Group by artist + date → sum daily streams
    {
        "$group": {
            "_id": {
                "artist_id": "$artist_id",
                "artist_name": "$artist_name",
                "date": "$date"
            },
            "daily_streams": {"$sum": "$daily"}
        }
    },

    # 2. Group by artist_id → build the streams array
    {
        "$group": {
            "_id": "$_id.artist_id",
            "artist_name": {"$first": "$_id.artist_name"},
            "streams": {
                "$push": {
                    "date": "$_id.date",
                    "daily_streams": "$daily_streams"
                }
            }
        }
    },

    # 3. Sort the streams array by date
    {
        "$project": {
            "_id": 0,
            "artist_id": "$_id",
            "artist_name": 1,
            "streams": {
                "$sortArray": {
                    "input": "$streams",
                    "sortBy": { "date": 1 }
                }
            }
        }
    },

    # 4. Sort artists alphabetically by name
    {"$sort": {"artist_name": 1}}
]

# %%
source_col = db.artist_daily_streams
target_col = db.artist_time_series   

results = list(source_col.aggregate(pipeline))

target_col.delete_many({})  # clears old results
target_col.insert_many(results)

# print("Aggregation result stored in 'artist_time_series' collection.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 4
#       1 source_col = db.artist_daily_streams
#       2 target_col = db.artist_time_series
# ----> 4 results = list(source_col.aggregate(pipeline))
#       6 target_col.delete_many({})  # clears old results
#       7 target_col.insert_many(results)
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/synchronous/command_cursor.py:342, in CommandCursor.__next__(self)
#     341 def __next__(self) -> _DocumentType:
# --> 342     return self.next()
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/synchronous/command_cursor.py:335, in CommandCursor.next(self)
#     333 # Block until a document is returnable.
#     334 while self.alive:
# --> 335     doc = self._try_next(True)
#     336     if doc is not None:
#     337         return doc
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/synchronous/command_cursor.py:347, in CommandCursor._try_next(self, get_more_allowed)
#     345 """Advance the cursor blocking for at most one getMore command."""
#     346 if not len(self._data) and not self._killed and get_more_allowed:
# --> 347     self._refresh()
#     348 if len(self._data):
#     349     return self._data.popleft()
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/synchronous/command_cursor.py:307, in CommandCursor._refresh(self)
#     305     dbname, collname = self._ns.split(".", 1)
#     306     read_pref = self._collection._read_preference_for(self.session)
# --> 307     self._send_message(
#     308         self._getmore_class(
#     309             dbname,
#     310             collname,
#     311             self._batch_size,
#     312             self._id,
#     313             self._collection.codec_options,
#     314             read_pref,
#     315             self._session,
#     316             self._collection.database.client,
#     317             self._max_await_time_ms,
#     318             self._sock_mgr,
#     319             False,
#     320             self._comment,
#     321         )
#     322     )
#     323 else:  # Cursor id is zero nothing else to return
#     324     self._die_lock()
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/synchronous/command_cursor.py:254, in CommandCursor._send_message(self, operation)
#     252 client = self._collection.database.client
#     253 try:
# --> 254     response = client._run_operation(
#     255         operation, self._unpack_response, address=self._address
#     256     )
#     257 except OperationFailure as exc:
#     258     if exc.code in _CURSOR_CLOSED_ERRORS:
#     259         # Don't send killCursors because the cursor is already closed.
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:1932, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1922     operation.reset()  # Reset op in case of retry.
#    1923     return server.run_operation(
#    1924         conn,
#    1925         operation,
#    (...)   1929         self,
#    1930     )
# -> 1932 return self._retryable_read(
#    1933     _cmd,
#    1934     operation.read_preference,
#    1935     operation.session,  # type: ignore[arg-type]
#    1936     address=address,
#    1937     retryable=isinstance(operation, _Query),
#    1938     operation=operation.name,
#    1939 )
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:2041, in MongoClient._retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    2036 # Ensure that the client supports retrying on reads and there is no session in
#    2037 # transaction, otherwise, we will not support retry behavior for this call.
#    2038 retryable = bool(
#    2039     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    2040 )
# -> 2041 return self._retry_internal(
#    2042     func,
#    2043     session,
#    2044     None,
#    2045     operation,
#    2046     is_read=True,
#    2047     address=address,
#    2048     read_pref=read_pref,
#    2049     retryable=retryable,
#    2050     operation_id=operation_id,
#    2051 )
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:2008, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1971 @_csot.apply
#    1972 def _retry_internal(
#    1973     self,
#    (...)   1982     operation_id: Optional[int] = None,
#    1983 ) -> T:
#    1984     """Internal retryable helper for all client transactions.
#    1985
#    1986     :param func: Callback function we want to retry
#    (...)   1995     :return: Output of the calling func()
#    1996     """
#    1997     return _ClientConnectionRetryable(
#    1998         mongo_client=self,
#    1999         func=func,
#    2000         bulk=bulk,
#    2001         operation=operation,
#    2002         is_read=is_read,
#    2003         session=session,
#    2004         read_pref=read_pref,
#    2005         address=address,
#    2006         retryable=retryable,
#    2007         operation_id=operation_id,
# -> 2008     ).run()
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:2745, in _ClientConnectionRetryable.run(self)
#    2743 self._check_last_error(check_csot=True)
#    2744 try:
# -> 2745     return self._read() if self._is_read else self._write()
#    2746 except ServerSelectionTimeoutError:
#    2747     # The application may think the write was never attempted
#    2748     # if we raise ServerSelectionTimeoutError on the retry
#    2749     # attempt. Raise the original exception instead.
#    2750     self._check_last_error()
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:2906, in _ClientConnectionRetryable._read(self)
#    2898 if self._retrying:
#    2899     _debug_log(
#    2900         _COMMAND_LOGGER,
#    2901         message=f"Retrying read attempt number {self._attempt_number}",
#    (...)   2904         operationId=self._operation_id,
#    2905     )
# -> 2906 return self._func(self._session, self._server, conn, read_pref)
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:1923, in MongoClient._run_operation.<locals>._cmd(_session, server, conn, read_preference)
#    1916 def _cmd(
#    1917     _session: Optional[ClientSession],
#    1918     server: Server,
#    1919     conn: Connection,
#    1920     read_preference: _ServerMode,
#    1921 ) -> Response:
#    1922     operation.reset()  # Reset op in case of retry.
# -> 1923     return server.run_operation(
#    1924         conn,
#    1925         operation,
#    1926         read_preference,
#    1927         self._event_listeners,
#    1928         unpack_res,
#    1929         self,
#    1930     )
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/synchronous/helpers.py:47, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      44 from pymongo.synchronous.pool import Connection
#      46 try:
# ---> 47     return func(*args, **kwargs)
#      48 except OperationFailure as exc:
#      49     if no_reauth:
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/synchronous/server.py:208, in Server.run_operation(self, conn, operation, read_preference, listeners, unpack_res, client)
#     206 else:
#     207     conn.send_message(data, max_doc_size)
# --> 208     reply = conn.receive_message(request_id)
#     210 # Unpack and check for command errors.
#     211 if use_cmd:
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/synchronous/pool.py:469, in Connection.receive_message(self, request_id)
#     467 # Catch KeyboardInterrupt, CancelledError, etc. and cleanup.
#     468 except BaseException as error:
# --> 469     self._raise_connection_failure(error)
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/synchronous/pool.py:466, in Connection.receive_message(self, request_id)
#     461 """Receive a raw BSON message or raise ConnectionFailure.
#     462
#     463 If any exception is raised, the socket is closed.
#     464 """
#     465 try:
# --> 466     return receive_message(self, request_id, self.max_message_size)
#     467 # Catch KeyboardInterrupt, CancelledError, etc. and cleanup.
#     468 except BaseException as error:
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/network_layer.py:759, in receive_message(conn, request_id, max_message_size)
#     757         deadline = None
#     758 # Ignore the response's request id.
# --> 759 length, _, response_to, op_code = _UNPACK_HEADER(receive_data(conn, 16, deadline))
#     760 # No request_id for exhaust cursor "getMore".
#     761 if request_id is not None:
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/network_layer.py:353, in receive_data(conn, length, deadline)
#     350             short_timeout = _POLL_TIMEOUT
#     351         conn.set_conn_timeout(short_timeout)
# --> 353     chunk_length = conn.conn.recv_into(mv[bytes_read:])
#     354 except BLOCKING_IO_ERRORS:
#     355     if conn.cancel_context.cancelled:
#
# File /opt/anaconda3/envs/kl2025/lib/python3.13/site-packages/pymongo/network_layer.py:469, in NetworkingInterface.recv_into(self, buffer)
#     468 def recv_into(self, buffer: bytes) -> int:
# --> 469     return self.conn.recv_into(buffer)
#
# KeyboardInterrupt:

# %%
results[5]
# Out:
# {'artist_name': 'Chance the Rapper',
#  'artist_id': '1anyVhU62p31KFi8MEzkbf',
#  'streams': [{'date': '2025-11-30', 'daily_streams': 2307309},
#   {'date': '2025-12-01', 'daily_streams': 2307309},
#   {'date': '2025-12-02', 'daily_streams': 1406376},
#   {'date': '2025-12-03', 'daily_streams': 703188}],
#  '_id': ObjectId('693216a64de81cf692a3f9f3')}

# %%
# Optiional for data files export
import pandas as pd

rows = []

for doc in results:  # results is a list of MongoDB documents
    artist_id = doc["artist_id"]
    artist_name = doc["artist_name"]

    for entry in doc["streams"]:
        rows.append({
            "artist_id": artist_id,
            "artist_name": artist_name,
            "date": entry["date"],
            "daily_streams": entry["daily_streams"]
        })

df = pd.DataFrame(rows)
df.head()
# Out:
#                 artist_id artist_name        date  daily_streams
# 0  17lzZA2AlOHwCwFALHttmp    2 Chainz  2025-11-30        3033624
# 1  17lzZA2AlOHwCwFALHttmp    2 Chainz  2025-12-01        3033624
# 2  17lzZA2AlOHwCwFALHttmp    2 Chainz  2025-12-02        2022416
# 3  17lzZA2AlOHwCwFALHttmp    2 Chainz  2025-12-03         925735
# 4  6lcwlkAjBPSKnFBZjjZFJs      Alex G  2025-11-30        6667881

# %%
df.to_csv("all_artists_streams.csv", index=False)
